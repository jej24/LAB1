# %% [markdown]
# <a href="https://colab.research.google.com/github/jej24/LAB1/blob/master/Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***LAB 1***
#
#
# INTEGRANTES:
#
# - **JORGE ROMERO**
#
# - **ALEJANDRO LOPEZ**
#
# - **NESTOR MARTINEZ**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

path='/content/drive/My Drive/PDI/LAB1/'
os.chdir(path)
# !pwd
# %matplotlib inline
# Out:
# /content/drive/My Drive/PDI/LAB1

# %%
def display22(a,b,title1="Orginial", title2="Edited"):
    plt.figure(figsize=(10,10))
    plt.subplot(121), plt.imshow(a, cmap='gray'),plt.title(title1)
    plt.xticks([]),plt.yticks([])
    plt.subplot(122), plt.imshow(b, cmap='gray'), plt.title(title2)
    plt.xticks([]),plt.yticks([])
    plt.show()

# %%
def display4(a, b, c, d, title1= "Original", title2 = "Editado", title3 = "Editado1", title4 = "Editado2"):
   plt.figure(figsize=(20,20))
   plt.subplot(141), plt.imshow(a, cmap='gray'), plt.title(title1)
   plt.xticks([]), plt.yticks([])
   plt.subplot(142), plt.imshow(b, cmap='gray'), plt.title(title2)
   plt.xticks([]), plt.yticks([])
   plt.subplot(143), plt.imshow(c, cmap='gray'), plt.title(title3)
   plt.xticks([]), plt.yticks([])
   plt.subplot(144), plt.imshow(d, cmap='gray'), plt.title(title4)
   plt.xticks([]), plt.yticks([])
   plt.show()

# %%
def readRGB(imgPath):
    img = cv2.imread(imgPath)
    img =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    return img

# %% [markdown]
# ***PRIMER PUNTO.***

# %% [markdown]
# **`*BORDES HORIZONTALES*`**

# %%
img = cv2.imread("furi.jpg",0)

kernel_sharpening = np.array([[-1, -2, -1],
                              [ 0,  0,  0],
                              [1,   2,  1]])
 
#display image
sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %% [markdown]
# ***BORDE VERTICAL***

# %%
img = cv2.imread("furi.jpg",0)

kernel_sharpening = np.array([[-1, 0, 1],
                              [-2, 0, 2],
                              [-1, 0, 1]])

#display image

sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %% [markdown]
# ***BORDE DIAGONAL***

# %%
img = cv2.imread("furi.jpg",0)

kernel_sharpening = np.array([[-1, -1, -1],
                              [-1,  8, -1],
                              [-1, -1, -1]])

#display image

sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %% [markdown]
# ***BORDES HORIZONTALES***

# %%
img = cv2.imread("furi2.jpg",0)

kernel_sharpening = np.array([[-1, -2, -1],
                              [ 0,  0,  0],
                              [1,   2,  1]])
 
#display image
sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %% [markdown]
# ***BORDES VERTICALES***

# %%
img = cv2.imread("furi2.jpg",0)

kernel_sharpening = np.array([[-1, 0, 1],
                              [-2, 0, 2],
                              [-1, 0, 1]])

#display image

sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %% [markdown]
# ***BORDES DIAGONALES***

# %%
img = cv2.imread("furi2.jpg",0)

kernel_sharpening = np.array([[-1, -1, -1],
                              [-1,  8, -1],
                              [-1, -1, -1]])

#display image

sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %% [markdown]
# ***BORDES HORIZONTALES***

# %%
img = cv2.imread("furi3.jpg",0)

kernel_sharpening = np.array([[-1, -2, -1],
                              [ 0,  0,  0],
                              [1,   2,  1]])
 
#display image
sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %% [markdown]
# ***BORDES VERTICALES***

# %%
img = cv2.imread("furi3.jpg",0)

kernel_sharpening = np.array([[-1, 0, 1],
                              [-2, 0, 2],
                              [-1, 0, 1]])

#display image

sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %% [markdown]
# ***BORDES DIAGONALES***

# %%
img = cv2.imread("furi3.jpg",0)

kernel_sharpening = np.array([[-1, -1, -1],
                              [-1,  8, -1],
                              [-1, -1, -1]])

#display image

sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %% [markdown]
# *LOS BORDES VERTICALES Y HORIZONTALES SE NOTAN DE MARCADOS EN CADA UNA DE LAS IMAGENES,PERO*
#
# *AL APLICAR LOS **BORDES DIAGONALES** SE NOTAN MAS DETALLES EN CADA UNO DE LOS CASOS*.

# %% [markdown]
# # **PUNTO 2**

# %%
# READ DE IMAGE

img = cv2.imread("cabeza.png",0)

#apply the 3x3 median filter on the image

median = cv2.medianBlur(median, 7)

#display image

display22(img, median)

# %%
# READ DE IMAGE

img = cv2.imread("sal.png",0)

#apply the 3x3 median filter on the image

#median2 = cv2.medianBlur(img, 3)
#median2 = cv2.medianBlur(median2, 3)
#median2 = cv2.medianBlur(median2, 3)
median2 = cv2.medianBlur(median2, 5)

display22(img, median2)

# %%
# READ DE IMAGE

img = cv2.imread("sal2.png",0)

#apply the 3x3 median filter on the image

median3 = cv2.medianBlur(img, 3)
#median2 = cv2.medianBlur(median2, 3)
#median2 = cv2.medianBlur(median2, 3)
median3 = cv2.medianBlur(median3, 5)

display22(img, median3)

# %%
# READ DE IMAGE

img = cv2.imread("sal3.png",0)

#apply the 3x3 median filter on the image



dst = cv2.blur(img,(21,21))
 
row, column = dst.shape
img1 = np.zeros((row, column), dtype ='uint8')
   
min_range = 128
max_range = 255
   
   
for i in range(row):
   for j in range(column):
       if dst[i, j]>min_range:
           img1[i,j] = 255
       else:
           img1[i,j] = 0


#display image

display22(dst,img1)

# %%
# READ DE IMAGE

img = cv2.imread("sal5.png",0)

#apply the 3x3 median filter on the image

median5 = cv2.medianBlur(img, 3)
#median2 = cv2.medianBlur(median2, 3)
#median2 = cv2.medianBlur(median2, 3)
median5 = cv2.medianBlur(median5, 3)

bilateral = cv2.bilateralFilter(median5,9,75,75)


display22(img, bilateral)

# %%
# READ DE IMAGE

img = cv2.imread("sal4.png",0)

#apply the 3x3 median filter on the image

median6 = cv2.medianBlur(img, 3)
#median2 = cv2.medianBlur(median2, 3)
median6 = cv2.medianBlur(median6, 7)
median6 = cv2.medianBlur(median6, 7)

kernel_sharpening = np.array([[-1,-1,-1],
                              [-1, 9,-1],
                              [-1,-1,-1]])

#display image

sharpened = cv2.filter2D(median6, -1, kernel_sharpening)
display4(img, median6, sharpened, img )

# %% [markdown]
# # ***PUNTO 3***

# %% [markdown]
# ***FILTRO PASA BAJOS***

# %%
img = cv2.imread('furi.jpg',0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20 * np.log(cv2.magnitude(dft_shift[:, : , 0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols = fils/2, cols/2

##creemos una mascara con un  centro cuadrado de 1 y el resto ceros
mask = np.zeros((fils, cols,2), np.uint8)
mask[np.int32(centfils)-500:np.int32(centfils)+500, np.int32(centcols)-500:np.int32(centcols+500)]=1

##apliquemos la mascara y luego obtenemos la inversa DFT
fshift = dft_shift*mask
fshift_mask_mag = 2000 * np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])


display4(img, img_back, fshift_mask_mag, magnitude_spectrum)

# %% [markdown]
# ***FILTRO PASA ALTOS***

# %%
img = cv2.imread('furi.jpg',0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20 * np.log(cv2.magnitude(dft_shift[:, : , 1], dft_shift[:,:,0]))
fils, cols = img.shape
centfils, centcols = fils/2, cols/2

##creemos una mascara con un  centro cuadrado de 1 y el resto ceros
mask = np.ones((fils, cols,2), np.uint8)
mask[np.int32(centfils)-100:np.int32(centfils)+100, np.int32(centcols)-100:np.int32(centcols+100)]=0

##apliquemos la mascara y luego obtenemos la inversa DFT
fshift = dft_shift*mask
fshift_mask_mag = 2000 * np.log(cv2.magnitude(fshift[:,:,1], fshift[:,:,0]))

f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,1], img_back[:,:,0])


display22(img, magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %% [markdown]
# **FILTRO PASA BAJOS**

# %%
img = cv2.imread('furi2.jpg',0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20 * np.log(cv2.magnitude(dft_shift[:, : , 0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols = fils/2, cols/2

##creemos una mascara con un  centro cuadrado de 1 y el resto ceros
mask = np.zeros((fils, cols,2), np.uint8)
mask[np.int32(centfils)-500:np.int32(centfils)+500, np.int32(centcols)-500:np.int32(centcols+500)]=1

##apliquemos la mascara y luego obtenemos la inversa DFT
fshift = dft_shift*mask
fshift_mask_mag = 2000 * np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])


display22(img, magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %% [markdown]
# ***FILTRO PASA ALTOS***

# %%
img = cv2.imread('furi2.jpg',0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20 * np.log(cv2.magnitude(dft_shift[:, : , 1], dft_shift[:,:,0]))
fils, cols = img.shape
centfils, centcols = fils/2, cols/2

##creemos una mascara con un  centro cuadrado de 1 y el resto ceros
mask = np.ones((fils, cols,2), np.uint8)
mask[np.int32(centfils)-100:np.int32(centfils)+100, np.int32(centcols)-100:np.int32(centcols+100)]=0

##apliquemos la mascara y luego obtenemos la inversa DFT
fshift = dft_shift*mask
fshift_mask_mag = 2000 * np.log(cv2.magnitude(fshift[:,:,1], fshift[:,:,0]))

f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,1], img_back[:,:,0])


display22(img, magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %% [markdown]
# ***FILTRO PASA BAJOS***

# %%
img = cv2.imread('furi3.jpg',0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20 * np.log(cv2.magnitude(dft_shift[:, : , 0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols = fils/2, cols/2

##creemos una mascara con un  centro cuadrado de 1 y el resto ceros
mask = np.zeros((fils, cols,2), np.uint8)
mask[np.int32(centfils)-500:np.int32(centfils)+500, np.int32(centcols)-500:np.int32(centcols+500)]=1

##apliquemos la mascara y luego obtenemos la inversa DFT
fshift = dft_shift*mask
fshift_mask_mag = 2000 * np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])


display22(img, magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %% [markdown]
# ***FILTRO PASA ALTOS***

# %%
img = cv2.imread('furi3.jpg',0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20 * np.log(cv2.magnitude(dft_shift[:, : , 1], dft_shift[:,:,0]))
fils, cols = img.shape
centfils, centcols = fils/2, cols/2

##creemos una mascara con un  centro cuadrado de 1 y el resto ceros
mask = np.ones((fils, cols,2), np.uint8)
mask[np.int32(centfils)-100:np.int32(centfils)+100, np.int32(centcols)-100:np.int32(centcols+100)]=0

##apliquemos la mascara y luego obtenemos la inversa DFT
fshift = dft_shift*mask
fshift_mask_mag = 2000 * np.log(cv2.magnitude(fshift[:,:,1], fshift[:,:,0]))

f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,1], img_back[:,:,0])


display22(img, magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app
